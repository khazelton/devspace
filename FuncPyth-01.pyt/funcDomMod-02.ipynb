# %%
using Markdown
using InteractiveUtils
using Dates
using Statistics
using Pkg
Pkg.add("BenchmarkTools")
using BenchmarkTools
# Out:
#    Resolving package versions...
#    Installed BenchmarkTools ─ v1.6.0
#     Updating `~/Project.toml`
#   [6e4b80f9] + BenchmarkTools v1.6.0
#     Updating `~/Manifest.toml`
#   [6e4b80f9] + BenchmarkTools v1.6.0
#   [9abbd945] + Profile v1.11.0
# Precompiling project...
#     827.1 ms  ✓ ChainRulesCore
#    1350.7 ms  ✓ BenchmarkTools
#     534.2 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesCoreExt
#     601.6 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    1537.0 ms  ✓ Compose
#     821.1 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    1629.8 ms  ✓ GeneralizedGenerated
#     934.3 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#    1101.1 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#    1523.1 ms  ✓ LabelledArrays
#    5358.0 ms  ✓ ACSets
#            ✗ Catlab
#            ✗ AlgebraicPetri
#   11 dependencies successfully precompiled in 9 seconds. 116 already precompiled.
#   2 dependencies errored.
# ...

# %%
err
# Out:
# PkgPrecompileError: The following 1 direct dependency failed to precompile:
#
# AlgebraicPetri
#
# Failed to precompile AlgebraicPetri [4f99eebe-17bf-4e98-b6a1-2c4f205a959b] to "/Users/kh/.julia/compiled/v1.11/AlgebraicPetri/jl_7nqKKL".
# ERROR: LoadError: UndefVarError: `ThCategory` not defined in `Catlab.Theories`
# Stacktrace:
#   [1] top-level scope
#     @ :0
#   [2] #macroexpand#74
#     @ ./expr.jl:125 [inlined]
#   [3] macroexpand(m::Module, x::Any)
#     @ Base ./expr.jl:123
#   [4] var"@symbolic_model"(__source__::LineNumberNode, __module__::Module, decl::Any, theoryname::Any, body::Any)
#     @ GATlab.Models.SymbolicModels ~/.julia/packages/GATlab/fO07H/src/models/SymbolicModels.jl:235
#   [5] include(mod::Module, _path::String)
#     @ Base ./Base.jl:557
#   [6] include(x::String)
#     @ Catlab.Theories ~/.julia/packages/Catlab/jPXBM/src/theories/Theories.jl:6
#   [7] top-level scope
#     @ ~/.julia/packages/Catlab/jPXBM/src/theories/Theories.jl:37
# ...
